# %%
import pandas as pd

# %%
pbp = pd.read_csv('./raw_data/reduced/play_by_play.csv', sep=",")
# Out:
# /home/asmabdulgafor/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (28,30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
game_ids = lines.game_id

# %%
game_ids
# Out:
# 0        29600012
# 1        29600005
# 2        29600002
# 3        29600013
# 4        29600009
#            ...
# 28016    42200307
# 28017    42200401
# 28018    42200402
# 28019    42200403
# 28020    42200404
# Name: game_id, Length: 28021, dtype: int64

# %%
df_iter = pd.read_csv('./raw_data/raw/play_by_play.csv', sep=',', iterator=True, chunksize=1000000)

# %%
#iter_num = 1

df = pd.DataFrame()
while True:
    try:
        df0 = next(df_iter)
        df0 = df0[df0['score'].notnull()]
        df0 = df0[df0['game_id'].isin(game_ids)]
        
        #df0.to_csv(f'./raw_data/play_by_play{iter_num:02d}.csv', index=False)

        #print(f'{len(df0)} valid rows saved to csv')
        
        df = pd.concat([df,df0], axis=0)
        
        #iter_num = iter_num + 1
         
    except StopIteration:
            print("Finished loading data")
            break
# Out:
# /home/asmabdulgafor/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Finished loading data

# %%
df
# Out:
#            game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 12        29600012        13             1                   8       1
# 15        29600012        16             1                   5       1
# 22        29600012        24             3                  11       1
# 24        29600012        26             3                  12       1
# 28        29600012        29             1                   5       1
# ...            ...       ...           ...                 ...     ...
# 13592003  42200404       593             1                  79       4
# 13592005  42200404       596             3                  11       4
# 13592007  42200404       599             3                  12       4
# 13592010  42200404       602             1                  50       4
# 13592014  42200404       607            13                   0       4
#
#          wctimestring pctimestring  \
# 12           14:53 PM        10:40
# 15           14:53 PM        10:05
# ...

# %%
df.to_csv('./raw_data/reduced/play_by_play.csv', index=False)

# %%
df = pd.read_csv('./raw_data/reduced/play_by_play.csv', sep=',')
# Out:
# /home/asmabdulgafor/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (28,30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
noteams = df[df['player1_team_id'].isnull()]

# %%
noteams.head(n=10)
# Out:
#       game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 26   29600012       116            13                   0       1
# 27   29600012       117            12                   0       2
# 59   29600012       247            13                   0       2
# 60   29600012       248            12                   0       3
# 89   29600012       372            13                   0       3
# 90   29600012       373            12                   0       4
# 112  29600012       489            13                   0       4
# 134  29600005        97            13                   0       1
# 135  29600005        98            12                   0       2
# 166  29600005       223            13                   0       2
#
#     wctimestring pctimestring homedescription  \
# 26      15:15 PM         0:00             NaN
# 27      15:18 PM        12:00             NaN
# 59      15:47 PM         0:00             NaN
# 60      16:02 PM        12:00             NaN
# ...

# %%
noteams.to_csv('./raw_data/reduced/noteamid.csv', index=False)
